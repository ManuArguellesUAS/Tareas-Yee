# %%
#def mi_funcion(param1, param2):
    #instruccion1
    #instruccion2

def saludar(nombre):
    print(f"Hola, bienvenido {nombre}.")

def suma(x, y):
    print(f"La suma de {x} + {y} es {x + y}")

saludar("Manuel")
suma(5, 5)
# Out:
# Hola, bienvenido Manuel.
# La suma de 5 + 5 es 10

# %%
def suma2(x, y):
    return x + y

resultado = suma2(10, 20)

def division(x, y):
    return x//y, x % y

a, b = division(9,2)
print(a, b)
# Out:
# 4 1

# %%
def suma3(*arg):#puede tomar varios arguementos
    s=0
    for i in arg:
        s += i
    return s

resultado = suma3(-1,0,1,2,3,4)
print("La suma es:", resultado)
# Out:
# La suma es: 9

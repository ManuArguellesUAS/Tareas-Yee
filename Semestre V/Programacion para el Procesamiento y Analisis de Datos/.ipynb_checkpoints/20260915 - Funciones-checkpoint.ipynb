# %%
#def mi_funcion(param1, param2):
    #instruccion1
    #instruccion2

def saludar(nombre):
    print(f"Hola, bienvenido {nombre}.")

def suma(x, y):
    print("La suma es", x + y)

# %%
saludar("Manuel")
suma(5, 5)
# Out:
# Hola, bienvenido Manuel.
